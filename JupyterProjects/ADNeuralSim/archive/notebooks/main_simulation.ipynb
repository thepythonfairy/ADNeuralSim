# %%
import sys
sys.path.append('../modules')

from spike_train import generate_spike_train

spikes = generate_spike_train(duration_ms=1000, rate_hz=20)
print("Spike times (ms):", spikes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.append('../modules')
# ----> 4 from spike_train import generate_spike_train
#       6 spikes = generate_spike_train(duration_ms=1000, rate_hz=20)
#       7 print("Spike times (ms):", spikes)
#
# File C:\JupyterProjects\ADNeuralSim\notebooks\../modules\spike_train.py:1
# ----> 1 import numpy as np
#       3 def generate_spike_train(duration_ms=1000, rate_hz=10):
#       4     num_spikes = int(duration_ms/1000*rate_hz)
#
# ModuleNotFoundError: No module named 'numpy'
