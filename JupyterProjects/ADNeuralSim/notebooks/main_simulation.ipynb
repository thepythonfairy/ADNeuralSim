# %%
import sys
sys.path.append('../modules')

from spike_train import generate_spike_train

spikes = generate_spike_train(duration_ms=1000, rate_hz=20)
print("Spike times in ms:", spikes)
# Out:
# Spike times in ms: [ 38.58919004  42.63630058  73.00112376 108.59545772 154.79340372
#  159.69404775 180.06217329 379.29341391 470.84331458 520.77944893
#  526.69540759 555.42841698 579.37831021 630.90518493 708.55748224
#  765.19650762 768.25525105 827.90623836 923.64437518 944.67185936]
